# %% [markdown]
# <a align="center" href="https://ultralytics.com/hub" target="_blank">
# <img width="1024", src="https://github.com/ultralytics/assets/raw/main/im/ultralytics-hub.png"></a>
#
# <div align="center">
#
# [中文](https://docs.ultralytics.com/zh/hub/) | [한국어](https://docs.ultralytics.com/ko/hub/) | [日本語](https://docs.ultralytics.com/ja/hub/) | [Русский](https://docs.ultralytics.com/ru/hub/) | [Deutsch](https://docs.ultralytics.com/de/hub/) | [Français](https://docs.ultralytics.com/fr/hub/) | [Español](https://docs.ultralytics.com/es/hub/) | [Português](https://docs.ultralytics.com/pt/hub/) | [Türkçe](https://docs.ultralytics.com/tr/hub/) | [Tiếng Việt](https://docs.ultralytics.com/vi/hub/) | [العربية](https://docs.ultralytics.com/ar/hub/)
#
#   <a href="https://github.com/ultralytics/hub/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/hub/actions/workflows/ci.yml/badge.svg" alt="CI CPU"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/hub/blob/main/hub.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
# Welcome to the [Ultralytics](https://ultralytics.com/) HUB notebook!
#
# This notebook allows you to train Ultralytics [YOLO](https://github.com/ultralytics/ultralytics) 🚀 models using [HUB](https://hub.ultralytics.com/). Please browse the HUB <a href="https://docs.ultralytics.com/hub/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/hub/issues/new/choose">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# %pip install ultralytics
from ultralytics import YOLO, checks, hub

checks()  # Verify system setup for Ultralytics training
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.1/112.6 GB disk)

# %% [markdown]
# # Start
#
# ⚡ Login with your API key, load your YOLO 🚀 model, and start training in 3 lines of code!

# %%
hub.login('b42e02b5a56c145f6ae7513aae888cdf9f570fa970')

model = YOLO('https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec')
results = model.train()
# Out:
# requirements: Ultralytics requirement ['hub-sdk>=0.0.12'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 6 packages in 135ms
# Prepared 1 package in 17ms
# Installed 1 package in 1ms
#  + hub-sdk==0.0.24
#
# requirements: AutoUpdate success ✅ 0.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec 🚀
# Downloading https://storage.googleapis.com/ultralytics-hub.appspot.com/users/O35rXwTcsuSgnn1dFcjv7EGsyL72/models/f8mBBQ9g6KiWnrd4UMec/epoch-45.pt to 'weights/epoch-45.pt': 100% ━━━━━━━━━━━━ 10.3MB 7.9MB/s 1.3s
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=55, bgr=0.0, box=7.5, cache=None, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=https://storage.googleapis.com/ultralytics-hub.appspot.com/users/O35rXwTcsuSgnn1dFcjv7EGsyL72/datasets/wj4pk20uYdjJhF0qtAcP/Design1v3.zip, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=weights/epoch-45.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=weights/epoch-45.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://storage.googleapis.com/ultralytics-hub.appspot.com/users/O35rXwTcsuSgnn1dFcjv7EGsyL72/datasets/wj4pk20uYdjJhF0qtAcP/Design1v3.zip to 'Design1v3.zip': 100% ━━━━━━━━━━━━ 1.0GB 24.5MB/s 42.1s
# Unzipping Design1v3.zip to /content/datasets/Recycle Trash.v3i.yolov8...: 100% ━━━━━━━━━━━━ 31049/31049 2.8Kfiles/s 11.1s
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 28.9MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    432232  ultralytics.nn.modules.head.Detect           [8, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,591,400 parameters, 2,591,384 gradients, 6.4 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 101.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1383.7±834.6 MB/s, size: 39.5 KB)
# train: Scanning /content/datasets/Recycle Trash.v3i.yolov8/train/labels... 12381 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 12381/12381 2.5Kit/s 5.0s
# train: New cache created: /content/datasets/Recycle Trash.v3i.yolov8/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 606, len(boxes) = 22146. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 732.3±197.4 MB/s, size: 52.3 KB)
# val: Scanning /content/datasets/Recycle Trash.v3i.yolov8/valid/labels... 2051 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2051/2051 1.3Kit/s 1.6s
# val: New cache created: /content/datasets/Recycle Trash.v3i.yolov8/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 128, len(boxes) = 3725. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /content/runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0004296875), 87 bias(decay=0.0)
# Resuming training weights/epoch-45.pt from epoch 47 to 100 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      7.35G     0.7609     0.5712       1.09         11        640: 100% ━━━━━━━━━━━━ 226/226 1.0s/it 3:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.5s/it 28.2s
#                    all       2051       3725      0.805       0.78      0.831      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      7.65G     0.7722     0.5792      1.091         17        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.3s
#                    all       2051       3725      0.795      0.777      0.825      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      7.35G     0.7643     0.5738      1.091         19        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.2s
#                    all       2051       3725      0.819      0.771      0.833      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      7.71G     0.7656     0.5696      1.091         23        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.8s
#                    all       2051       3725      0.799      0.781      0.833      0.634
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      7.52G     0.7585     0.5702      1.086         19        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.7s
#                    all       2051       3725      0.827      0.766      0.832      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      7.69G     0.7567     0.5548      1.082         23        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.5s
#                    all       2051       3725      0.806      0.789      0.838      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      7.81G     0.7517     0.5524       1.08         18        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1it/s 18.0s
#                    all       2051       3725      0.814      0.792      0.842      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      7.62G     0.7443     0.5519      1.079         18        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.8s
#                    all       2051       3725      0.825      0.795       0.84      0.642
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      7.56G     0.7363     0.5359      1.073         22        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.2s
#                    all       2051       3725      0.807      0.808      0.837       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      7.25G     0.7349     0.5374      1.072         12        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.6s
#                    all       2051       3725      0.821      0.797      0.837      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100       7.6G     0.7387     0.5339      1.074         17        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.2s
#                    all       2051       3725      0.831      0.794      0.838      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      7.83G     0.7278     0.5368      1.069         14        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.5s
#                    all       2051       3725      0.841      0.793      0.843      0.644
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      7.23G     0.7306     0.5339      1.071         26        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.2s/it 22.1s
#                    all       2051       3725      0.836      0.797      0.848      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      7.57G     0.7193     0.5201      1.065         23        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.6s
#                    all       2051       3725       0.84      0.785       0.85      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      7.42G     0.7189     0.5189      1.062         19        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.4s
#                    all       2051       3725      0.864      0.763      0.849      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      7.21G     0.7197     0.5195      1.064         14        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.8s
#                    all       2051       3725      0.852      0.774      0.847      0.647
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      7.49G     0.7161     0.5158      1.062         16        640: 100% ━━━━━━━━━━━━ 226/226 1.0it/s 3:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.1s
#                    all       2051       3725      0.842      0.788      0.847      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      7.59G     0.7153     0.5088      1.061         23        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.4s
#                    all       2051       3725      0.843      0.796      0.846      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100       7.4G     0.7038     0.5042      1.058         16        640: 100% ━━━━━━━━━━━━ 226/226 1.0it/s 3:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.6s
#                    all       2051       3725      0.846      0.788      0.847      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      7.46G     0.7069     0.5045      1.059         22        640: 100% ━━━━━━━━━━━━ 226/226 1.0it/s 3:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.9s
#                    all       2051       3725      0.848      0.784      0.845      0.645
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      7.41G     0.6953     0.5016      1.054         27        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.9s
#                    all       2051       3725      0.849      0.788      0.844      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      7.49G     0.6994      0.497      1.056         34        640: 100% ━━━━━━━━━━━━ 226/226 1.0it/s 3:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.2s
#                    all       2051       3725      0.837      0.797      0.846      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100       7.4G     0.6948      0.494      1.057         17        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.9s
#                    all       2051       3725       0.83      0.801      0.846      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      7.21G     0.6956     0.4927      1.054         16        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.6s
#                    all       2051       3725      0.841      0.792      0.847      0.648
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      7.82G     0.6843     0.4846      1.045         41        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.4s
#                    all       2051       3725      0.835      0.795      0.847      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      7.48G     0.6901     0.4794      1.048         32        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.3s
#                    all       2051       3725       0.83        0.8      0.845      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      7.38G     0.6793     0.4767      1.044         16        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.7s
#                    all       2051       3725      0.833        0.8      0.846      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      7.47G     0.6782     0.4728      1.042         31        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1it/s 18.1s
#                    all       2051       3725       0.83      0.803      0.847      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      7.88G     0.6765     0.4686       1.04         16        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.5s
#                    all       2051       3725      0.838      0.804      0.847       0.65
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      7.58G     0.6713     0.4683      1.039         21        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1it/s 17.8s
#                    all       2051       3725      0.837      0.804      0.848      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      7.35G     0.6644     0.4604      1.035         25        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.6s
#                    all       2051       3725      0.842      0.805      0.849      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      7.37G     0.6645     0.4595      1.037         15        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.1s
#                    all       2051       3725      0.841      0.806      0.849      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      7.37G     0.6557     0.4506      1.031         18        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.2s
#                    all       2051       3725      0.838      0.807       0.85      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      7.42G     0.6563     0.4542      1.032         20        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.0s
#                    all       2051       3725      0.839      0.807      0.851      0.655
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      7.23G     0.6639      0.458      1.035         18        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.6s
#                    all       2051       3725      0.838      0.808      0.851      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      7.79G     0.6626     0.4566      1.036         22        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.6s
#                    all       2051       3725      0.844      0.807      0.851      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      7.21G     0.6613     0.4537      1.033         23        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.9s
#                    all       2051       3725      0.843      0.807      0.852      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      7.51G      0.657     0.4509      1.033         14        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.2s
#                    all       2051       3725      0.843      0.808      0.851      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100       7.5G     0.6487     0.4429      1.027         30        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.4s
#                    all       2051       3725      0.841      0.806      0.852      0.655
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      8.12G     0.6471     0.4415      1.027         18        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.0s
#                    all       2051       3725      0.842      0.808      0.852      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      7.52G     0.6443     0.4381      1.024         30        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.3s
#                    all       2051       3725      0.832      0.817      0.851      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      7.49G     0.6402     0.4326      1.022         16        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1it/s 17.7s
#                    all       2051       3725      0.837      0.813      0.851      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100       7.2G     0.6377     0.4339      1.025         10        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 20.3s
#                    all       2051       3725      0.834      0.816      0.852      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.56G     0.6332     0.4277      1.022         18        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.8s
#                    all       2051       3725      0.835      0.818      0.852      0.654
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      7.34G      0.566     0.3329       0.98          9        640: 100% ━━━━━━━━━━━━ 226/226 1.1it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.8s
#                    all       2051       3725      0.841      0.814      0.852      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.35G     0.5532     0.3208     0.9748         15        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.2s
#                    all       2051       3725      0.841      0.814      0.851      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      7.36G     0.5481     0.3159     0.9713         13        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.4s
#                    all       2051       3725      0.842      0.814      0.852      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      7.72G     0.5418     0.3089     0.9679          7        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.1s
#                    all       2051       3725      0.842      0.814      0.852      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      7.43G     0.5352     0.3033      0.963          8        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1it/s 17.2s
#                    all       2051       3725      0.843      0.813      0.853      0.655
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      7.54G     0.5287     0.2992     0.9584         11        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1it/s 17.8s
#                    all       2051       3725      0.843      0.811      0.853      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.33G     0.5247     0.2962     0.9528          8        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1it/s 17.5s
#                    all       2051       3725      0.842      0.813      0.854      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      7.59G     0.5245     0.2951     0.9555          6        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.9s
#                    all       2051       3725      0.841      0.814      0.853      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      7.51G     0.5176     0.2894     0.9547          8        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0it/s 18.8s
#                    all       2051       3725      0.841      0.817      0.854      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100       7.4G      0.518     0.2889     0.9532         10        640: 100% ━━━━━━━━━━━━ 226/226 1.2it/s 3:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.0s/it 19.1s
#                    all       2051       3725       0.84      0.817      0.854      0.655
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec
#
# 54 epochs completed in 3.384 hours.
# Optimizer stripped from /content/runs/detect/train2/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs/detect/train2/weights/best.pt, 5.5MB
#
# Validating /content/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,712 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1s/it 21.7s
#                    all       2051       3725      0.845      0.807      0.852      0.655
#                  paper        877       1650      0.948      0.931      0.966      0.782
#                  glass         27         62      0.755      0.697      0.759      0.604
#                  metal         81        125      0.951       0.88      0.931      0.867
#                  other         12         72      0.642      0.764        0.7      0.536
#                plastic        629       1316      0.959      0.911      0.969      0.848
#                  watch        117        172      0.888       0.88      0.919      0.631
#                   ring        112        131      0.801      0.595      0.761      0.378
#                    key        197        197      0.814      0.799      0.816      0.595
# Speed: 0.2ms preprocess, 2.4ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to /content/runs/detect/train2
# Ultralytics HUB: Syncing final model...
# : 100% ━━━━━━━━━━━━ 5.2MB 4.2MB/s 1.2s
# Ultralytics HUB: Done ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/f8mBBQ9g6KiWnrd4UMec 🚀
